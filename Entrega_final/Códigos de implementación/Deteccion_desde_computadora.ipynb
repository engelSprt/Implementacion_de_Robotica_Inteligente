# %%
#Se importan torch, necesario para hacer cargar el modelo
import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-178-ga199480 Python-3.8.0 torch-2.0.1+cu117 CPU
# Setup complete ✅ (4 CPUs, 7.5 GB RAM, 48.8/128.6 GB disk)

# %%
# Out:
# benchmarks.py	     detect.py		__pycache__	  train.py
# best.pt		     export.py		README.md	  tutorial.ipynb
# CITATION.cff	     hubconf.py		README.zh-CN.md   ultimo_modelo.pt
# classify	     LICENSE		requirements.txt  Untitled.ipynb
# CONTRIBUTING.md      models		runs		  utils
# convertirPTaONNX.py  nuevo.pt		segment		  val.py
# data		     nuevo.torchscript	setup.cfg

# %%
#Hacer reconocimiento sobre una imagen
#!python detect.py --weights best.pt --img 640 --conf 0.25 --source "imagen.jpg"

# %%
#Se ejeuta el script detec.py de yolov
#nuevo.pt es el modelo
# !python3.8 detect.py --weights nuevo.pt --source 0
# Out:
# detect: weights=['nuevo.pt'], source=0, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-178-ga199480 Python-3.8.0 torch-2.0.1+cu117 CPU
#
# Fusing layers...
# custom_YOLOv5s summary: 182 layers, 7268094 parameters, 0 gradients
# 1/1: 0...  Success (inf frames 640x480 at 30.00 FPS)
#
# 0: 480x640 (no detections), 224.1ms
# 0: 480x640 (no detections), 300.0ms
# 0: 480x640 (no detections), 201.8ms
# 0: 480x640 (no detections), 201.0ms
# 0: 480x640 (no detections), 201.0ms
# 0: 480x640 (no detections), 199.2ms
# 0: 480x640 (no detections), 194.5ms
# 0: 480x640 (no detections), 197.2ms
# 0: 480x640 (no detections), 195.9ms
# ...
